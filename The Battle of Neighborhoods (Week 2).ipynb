# %% [markdown]
# <h1 align=center><font size = 6>Capstone Project - The Battle of Neighborhoods (Week 2)</font></h1>

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Due to the **Covid-19 crisis**, many businesses have had to close. I have been able to appreciate this horrible situation especially in the neighborhood where I live.
#
# When the novel coronavirus pandemic initially hit back in March and politicians ordered all restaurants and bars to close to in-room dining, a panic soared throughout the hospitality industry. Thousands of establishments shut their doors immediately for indoor dining, leaving countless people out of work. Many questions arose: When could restaurants fully reopen? How many might not return? What would the landscape look like with so much restaurant vacancy?
#
# I'm going to analyze the number of food businesses in the area where I live to see if it would be a good business opportunity to open a restaurant at this moment. It is a good way to revive the economy and bring the neighborhood back to life.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# I am going to check the restaurants in my neighborhoods and analyze the most surrounding areas to conclude if there are business opportunities for food places at the moment.
#
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * number of and distance to different sports centers in the neighborhood, if any
#
# I will import the coordinates of my neighborhood and visualize using **Foursquare API** the restaurants and bars that are nearby. Also,I wil show the different sport centers as it is very typical to have a drink after doing sports with friends. I'm gonna use Folium for the graphics.

# %% [markdown]
# #### Import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.50)
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Let's visualize the restaurants that are nearby

# %%
address = 'Plaza De Peña Horcajo, Madrid, Spain'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of my neighborhood are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of my neighborhood are 40.4846746, -3.7218096.

# %%
map_lacoma = folium.Map(location=[latitude, longitude], zoom_start=15)
folium.Marker([latitude, longitude], popup='Point of interest').add_to(map_lacoma)

map_lacoma
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
radius = 1000
food_category = '4d4b7105d754a06374d81259'
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
import requests
results = requests.get(url).json()
items = results['response']['groups'][0]['items']

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(50)
# Out:
#                                 name              categories  \
# 0   El Viejo Almacén de Buenos Aires  Argentinian Restaurant
# 1                     Tras Os Montes      Seafood Restaurant
# 2                     La Alternativa                 Brewery
# 3                       Akira Comics              Comic Shop
# 4              CDM Go Fit Peñagrande    Gym / Fitness Center
# 5       La Maso Sport Center - Padel             Sports Club
# 6                           Singapur      Chinese Restaurant
# 7                     Los Granadinos        Tapas Restaurant
# 8                        Cala Millor                  Bakery
# 9            Body Factory Mirasierra                     Gym
# 10           The Clover Irish Tavern                     Pub
# 11                 Churreria Avenida                    Café
# 12                   Mesón Las Vegas      Spanish Restaurant
# 13                  Ginos Mirasierra      Italian Restaurant
# 14                       Peggy Sue's                   Diner
# 15                  Supercor Express       Food & Drink Shop
# 16                            Bonsai      Chinese Restaurant
# 17                           Lazcano                    Café
# 18                  La Ponderosa Bar        Tapas Restaurant
# 19                    Los Granadinos                     Bar
# 20             Polideportivo La Masó      Athletics & Sports
# 21                   SuperCor Exprés       Convenience Store
# 22                Cervecería Granada                     Bar
# 23         Campo de Fútbol de Lacoma               BBQ Joint
# 24        Polideportivo Isla Tabarca            Soccer Field
# 25                        El Mirador              Restaurant
# 26                   VIPS Mirasierra            Burger Joint
# 27  Instalación Deportiva Valdeyeros            Soccer Field
# 28               Starving Conciertos                     Bar
# 29           Ginos Monforte de Lemos      Italian Restaurant
# 30                       Bar Carmelo          Breakfast Spot
# 31                              Gama           Grocery Store
# 32          Restaurante Tres Carro's              Restaurant
#
#                                         address  cc                   city  \
# 0                 C. Ramón Gómez de la Serna, 4  ES                 Madrid
# 1                          Senda del Infante 28  ES                 Madrid
# 2                                           NaN  ES  Madrid Centro, Madrid
# 3                            Av de Betanzos, 74  ES                 Madrid
# 4                Avenida Monforte de Lemos, 184  ES                 Madrid
# 5                          Calle de la Masó, 34  ES                 Madrid
# 6                    C. Mirador de la Reina, 99  ES                 Madrid
# 7             Av del Cardenal Herrera Oria, 248  ES                 Madrid
# 8                       C. Fermín Caballero, 70  ES                 Madrid
# 9                       C/ Valle de en medio 15  ES                 Madrid
# 10                C. Valle de Pinares Llanos, 8  ES                 Madrid
# 11                        C. Cerro Minguete, 16  ES                 Madrid
# 12  Calle de la Isla de Arosa, 29, 28035 Madrid  ES                 Madrid
# 13              C. del Mirador de la Reina, 107  ES                 Madrid
# 14                    Av. Monforte de Lemos 185  ES                 Madrid
# 15                         C/ Cerro Minguete, 9  ES                 Madrid
# 16                      Valle Pinares Llanos, 8  ES                 Madrid
# 17                                          NaN  ES                    NaN
# 18               Av. Cardenal Herrera Oria, 231  ES                 Madrid
# 19                  C. Leopoldo Alas Clarín, 53  ES                 Madrid
# 20                               C. La Masó, 80  ES                 Madrid
# 21                                          NaN  ES                    NaN
# 22                                          NaN  ES                 Madrid
# 23                Calle Ramón Gómez de la Serna  ES                 Madrid
# 24                                          NaN  ES                    NaN
# 25                 Calle Mirador de la Reina 99  ES                 Madrid
# 26                  C. Mirador de la Reina, 107  ES                 Madrid
# 27                            Rosalía de Castro  ES                 Madrid
# 28                      C. Fermin Caballero, 69  ES                 Madrid
# 29                   Av. Monforte de Lemos, 193  ES                 Madrid
# 30                            Isla de Saipán 73  ES                 Madrid
# 31                                    La maso 2  ES                 Madrid
# 32                   Alfonso Rodríguez Castelao  ES                    NaN
#
#    country                    crossStreet  distance  \
# 0   España                            NaN       416
# 1   España                            NaN       730
# 2   España                            NaN       366
# 3   España               Fermín Caballero       725
# 4   España                            NaN       923
# 5   España                            NaN       863
# 6   España                            NaN       555
# 7   España                            NaN       402
# 8   España                   Av. Betanzos       861
# 9   España                            NaN       548
# 10  España                            NaN       303
# 11  España                            NaN       356
# 12  España                            NaN       650
# 13  España                            NaN       660
# 14  España                            NaN       960
# 15  España                            NaN       308
# 16  España                            NaN       330
# 17  España                            NaN       601
# 18  España                            NaN       459
# 19  España                            NaN        74
# 20  España  Av. Ventisquero de la Condesa       546
# 21  España                            NaN       985
# 22  España                            NaN       131
# 23  España                            NaN       139
# 24  España                            NaN       871
# 25  España        Cerro de Álamos Blancos       543
# 26  España                            NaN       663
# 27  España                            NaN       725
# 28  España                            NaN       937
# 29  España                            NaN       980
# 30  España                            NaN       923
# 31  España                            NaN       965
# 32  España                            NaN       983
#
#                                      formattedAddress  \
# 0   [C. Ramón Gómez de la Serna, 4, 28035 Madrid M...
# 1   [Senda del Infante 28, 28049 Madrid Madrid, Es...
# 2                      [Madrid Centro Madrid, España]
# 3   [Av de Betanzos, 74 (Fermín Caballero), 28034 ...
# 4   [Avenida Monforte de Lemos, 184, 28035 Madrid ...
# 5   [Calle de la Masó, 34, 28034 Madrid Madrid, Es...
# 6   [C. Mirador de la Reina, 99, 28035 Madrid Madr...
# 7   [Av del Cardenal Herrera Oria, 248, 28035 Madr...
# 8   [C. Fermín Caballero, 70 (Av. Betanzos), 28034...
# 9    [C/ Valle de en medio 15, Madrid Madrid, España]
# 10  [C. Valle de Pinares Llanos, 8, 28035 Madrid M...
# 11  [C. Cerro Minguete, 16, 28035 Madrid Madrid, E...
# 12  [Calle de la Isla de Arosa, 29, 28035 Madrid, ...
# 13  [C. del Mirador de la Reina, 107, 28035 Madrid...
# 14  [Av. Monforte de Lemos 185, 28035 Madrid Madri...
# 15  [C/ Cerro Minguete, 9, 28035 Madrid Madrid, Es...
# 16  [Valle Pinares Llanos, 8, 28035 Madrid Madrid,...
# 17                                           [España]
# 18  [Av. Cardenal Herrera Oria, 231, 28034 Madrid ...
# 19  [C. Leopoldo Alas Clarín, 53, 28035 Madrid Mad...
# 20  [C. La Masó, 80 (Av. Ventisquero de la Condesa...
# 21                                           [España]
# 22                            [Madrid Madrid, España]
# 23  [Calle Ramón Gómez de la Serna, Madrid Madrid,...
# 24                                           [España]
# 25  [Calle Mirador de la Reina 99 (Cerro de Álamos...
# 26  [C. Mirador de la Reina, 107, 28035 Madrid Mad...
# 27         [Rosalía de Castro, Madrid Madrid, España]
# 28  [C. Fermin Caballero, 69, 28029 Madrid Madrid,...
# 29  [Av. Monforte de Lemos, 193, 28035 Madrid Madr...
# 30   [Isla de Saipán 73, 28035 Madrid Madrid, España]
# 31                 [La maso 2, Madrid Madrid, España]
# 32               [Alfonso Rodríguez Castelao, España]
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 40.48112446689104...  40.481124 -3.723373
# 1   [{'label': 'display', 'lat': 40.49122842350793...  40.491228 -3.722157
# 2   [{'label': 'display', 'lat': 40.48678467998688...  40.486785 -3.718490
# 3   [{'label': 'display', 'lat': 40.48210086100509...  40.482101 -3.713938
# 4   [{'label': 'display', 'lat': 40.47706381409571...  40.477064 -3.717482
# 5   [{'label': 'display', 'lat': 40.489904, 'lng':...  40.489904 -3.714280
# 6   [{'label': 'display', 'lat': 40.48914619140871...  40.489146 -3.724716
# 7   [{'label': 'display', 'lat': 40.48112023451070...  40.481120 -3.720963
# 8   [{'label': 'display', 'lat': 40.48215283169287...  40.482153 -3.712195
# 9   [{'label': 'display', 'lat': 40.48838053202037...  40.488381 -3.717541
# 10  [{'label': 'display', 'lat': 40.4858706510018,...  40.485871 -3.718590
# 11  [{'label': 'display', 'lat': 40.487003559763, ...  40.487004 -3.718925
# 12  [{'label': 'display', 'lat': 40.48034557270606...  40.480346 -3.716651
# 13  [{'label': 'display', 'lat': 40.49059779325799...  40.490598 -3.722262
# 14  [{'label': 'display', 'lat': 40.47651545133406...  40.476515 -3.718117
# 15  [{'label': 'display', 'lat': 40.48700313082754...  40.487003 -3.719826
# 16  [{'label': 'display', 'lat': 40.48579063622070...  40.485791 -3.718186
# 17  [{'label': 'display', 'lat': 40.48818724029966...  40.488187 -3.716407
# 18  [{'label': 'display', 'lat': 40.48212002479462...  40.482120 -3.717547
# 19  [{'label': 'display', 'lat': 40.48454075118334...  40.484541 -3.722673
# 20  [{'label': 'display', 'lat': 40.48450797800188...  40.484508 -3.715361
# 21  [{'label': 'display', 'lat': 40.4759056665114,...  40.475906 -3.720184
# 22  [{'label': 'display', 'lat': 40.48474093558645...  40.484741 -3.720256
# 23  [{'label': 'display', 'lat': 40.48484263040647...  40.484843 -3.723446
# 24  [{'label': 'display', 'lat': 40.47687381375908...  40.476874 -3.720949
# 25  [{'label': 'display', 'lat': 40.489086, 'lng':...  40.489086 -3.724573
# 26  [{'label': 'display', 'lat': 40.49061956122534...  40.490620 -3.722371
# 27  [{'label': 'display', 'lat': 40.48385972087871...  40.483860 -3.730312
# 28  [{'label': 'display', 'lat': 40.48199789977096...  40.481998 -3.711317
# 29  [{'label': 'display', 'lat': 40.47600665515477...  40.476007 -3.719769
# 30  [{'label': 'display', 'lat': 40.47923696814644...  40.479237 -3.730044
# 31  [{'label': 'display', 'lat': 40.48176480591085...  40.481765 -3.732548
# 32  [{'label': 'display', 'lat': 40.48205674009662...  40.482057 -3.732905
#
#    neighborhood postalCode   state                        id
# 0           NaN      28035  Madrid  4b8cf54af964a52047e232e3
# 1           NaN      28049  Madrid  4c5488d1728920a1c53ee782
# 2           NaN        NaN  Madrid  50522811e4b0e2b08b3212b4
# 3           NaN      28034  Madrid  4b5f3ab6f964a520c9ae29e3
# 4   Peña Grande      28035  Madrid  59dc7ed1f62e096d40bace40
# 5           NaN      28034  Madrid  57868bb4498e8ddd7b00590d
# 6           NaN      28035  Madrid  4c11515b8559ef3b75b66a53
# 7           NaN      28035  Madrid  4b74653ef964a520e0d92de3
# 8           NaN      28034  Madrid  4d43ff7ebbb1a143b41a4172
# 9           NaN        NaN  Madrid  4d034a74347da1cd91a4248f
# 10          NaN      28035  Madrid  4c2fcbd266e40f472a9ac28b
# 11          NaN      28035  Madrid  4f3e3e56e4b0a4b08299a77a
# 12          NaN      28035  Madrid  4ee0faa177c804cac6dbf9b3
# 13          NaN      28035  Madrid  568500f3498e7291bb023134
# 14          NaN      28035  Madrid  50040fdde4b0095178ff8474
# 15          NaN      28035  Madrid  4bd48507cfa7b713eb3a24da
# 16          NaN      28035  Madrid  4bbf83994cdfc9b6e6639121
# 17          NaN        NaN     NaN  4d79d6b80ceba1cda635b858
# 18          NaN      28034  Madrid  4cde867369136dcbe9acd6e6
# 19          NaN      28035  Madrid  4da6e6525da37feee891e3e2
# 20          NaN      28034  Madrid  4bc63708b387d13aec7fc1e8
# 21          NaN        NaN     NaN  506c76b9498e3642a5ce6a79
# 22          NaN        NaN  Madrid  4c7044203444370403a5235f
# 23          NaN        NaN  Madrid  4dc6cfcc887717c880455ed1
# 24          NaN        NaN     NaN  4c8fad0cd2aea0937e98d869
# 25          NaN        NaN  Madrid  4e13444418a84f0f03248847
# 26          NaN      28035  Madrid  4b6acd85f964a5200ee12be3
# 27          NaN        NaN  Madrid  4e70ef3ad22d2dfc31e1fe1f
# 28          NaN      28029  Madrid  4e3e03a4ae604542366e3d90
# 29          NaN      28035  Madrid  4d6e5e602c542d43415a7aa6
# 30          NaN      28035  Madrid  4eca008e775bf65c0663eae3
# 31          NaN        NaN  Madrid  4dca7cdc7d8bc0c0b87ddd4f
# 32          NaN        NaN     NaN  54e0a07c498edc3a986299aa

# %%
#Cleaning
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Comic Shop') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Bakery') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Café') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Food & Drink Shop') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Convenience Store') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'BBQ Joint') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Soccer Field') ].index , inplace=True)
dataframe_filtered.drop(dataframe_filtered[ (dataframe_filtered['categories'] == 'Grocery Store') ].index , inplace=True)
dataframe_filtered.reset_index(inplace=True, drop=True)
dataframe_filtered.head(32)
# Out:
#                                 name              categories  \
# 0   El Viejo Almacén de Buenos Aires  Argentinian Restaurant
# 1                     Tras Os Montes      Seafood Restaurant
# 2                     La Alternativa                 Brewery
# 3              CDM Go Fit Peñagrande    Gym / Fitness Center
# 4       La Maso Sport Center - Padel             Sports Club
# 5                           Singapur      Chinese Restaurant
# 6                     Los Granadinos        Tapas Restaurant
# 7            Body Factory Mirasierra                     Gym
# 8            The Clover Irish Tavern                     Pub
# 9                    Mesón Las Vegas      Spanish Restaurant
# 10                  Ginos Mirasierra      Italian Restaurant
# 11                       Peggy Sue's                   Diner
# 12                            Bonsai      Chinese Restaurant
# 13                  La Ponderosa Bar        Tapas Restaurant
# 14                    Los Granadinos                     Bar
# 15             Polideportivo La Masó      Athletics & Sports
# 16                Cervecería Granada                     Bar
# 17                        El Mirador              Restaurant
# 18                   VIPS Mirasierra            Burger Joint
# 19               Starving Conciertos                     Bar
# 20           Ginos Monforte de Lemos      Italian Restaurant
# 21                       Bar Carmelo          Breakfast Spot
# 22          Restaurante Tres Carro's              Restaurant
#
#                                         address  cc                   city  \
# 0                 C. Ramón Gómez de la Serna, 4  ES                 Madrid
# 1                          Senda del Infante 28  ES                 Madrid
# 2                                           NaN  ES  Madrid Centro, Madrid
# 3                Avenida Monforte de Lemos, 184  ES                 Madrid
# 4                          Calle de la Masó, 34  ES                 Madrid
# 5                    C. Mirador de la Reina, 99  ES                 Madrid
# 6             Av del Cardenal Herrera Oria, 248  ES                 Madrid
# 7                       C/ Valle de en medio 15  ES                 Madrid
# 8                 C. Valle de Pinares Llanos, 8  ES                 Madrid
# 9   Calle de la Isla de Arosa, 29, 28035 Madrid  ES                 Madrid
# 10              C. del Mirador de la Reina, 107  ES                 Madrid
# 11                    Av. Monforte de Lemos 185  ES                 Madrid
# 12                      Valle Pinares Llanos, 8  ES                 Madrid
# 13               Av. Cardenal Herrera Oria, 231  ES                 Madrid
# 14                  C. Leopoldo Alas Clarín, 53  ES                 Madrid
# 15                               C. La Masó, 80  ES                 Madrid
# 16                                          NaN  ES                 Madrid
# 17                 Calle Mirador de la Reina 99  ES                 Madrid
# 18                  C. Mirador de la Reina, 107  ES                 Madrid
# 19                      C. Fermin Caballero, 69  ES                 Madrid
# 20                   Av. Monforte de Lemos, 193  ES                 Madrid
# 21                            Isla de Saipán 73  ES                 Madrid
# 22                   Alfonso Rodríguez Castelao  ES                    NaN
#
#    country                    crossStreet  distance  \
# 0   España                            NaN       416
# 1   España                            NaN       730
# 2   España                            NaN       366
# 3   España                            NaN       923
# 4   España                            NaN       863
# 5   España                            NaN       555
# 6   España                            NaN       402
# 7   España                            NaN       548
# 8   España                            NaN       303
# 9   España                            NaN       650
# 10  España                            NaN       660
# 11  España                            NaN       960
# 12  España                            NaN       330
# 13  España                            NaN       459
# 14  España                            NaN        74
# 15  España  Av. Ventisquero de la Condesa       546
# 16  España                            NaN       131
# 17  España        Cerro de Álamos Blancos       543
# 18  España                            NaN       663
# 19  España                            NaN       937
# 20  España                            NaN       980
# 21  España                            NaN       923
# 22  España                            NaN       983
#
#                                      formattedAddress  \
# 0   [C. Ramón Gómez de la Serna, 4, 28035 Madrid M...
# 1   [Senda del Infante 28, 28049 Madrid Madrid, Es...
# 2                      [Madrid Centro Madrid, España]
# 3   [Avenida Monforte de Lemos, 184, 28035 Madrid ...
# 4   [Calle de la Masó, 34, 28034 Madrid Madrid, Es...
# 5   [C. Mirador de la Reina, 99, 28035 Madrid Madr...
# 6   [Av del Cardenal Herrera Oria, 248, 28035 Madr...
# 7    [C/ Valle de en medio 15, Madrid Madrid, España]
# 8   [C. Valle de Pinares Llanos, 8, 28035 Madrid M...
# 9   [Calle de la Isla de Arosa, 29, 28035 Madrid, ...
# 10  [C. del Mirador de la Reina, 107, 28035 Madrid...
# 11  [Av. Monforte de Lemos 185, 28035 Madrid Madri...
# 12  [Valle Pinares Llanos, 8, 28035 Madrid Madrid,...
# 13  [Av. Cardenal Herrera Oria, 231, 28034 Madrid ...
# 14  [C. Leopoldo Alas Clarín, 53, 28035 Madrid Mad...
# 15  [C. La Masó, 80 (Av. Ventisquero de la Condesa...
# 16                            [Madrid Madrid, España]
# 17  [Calle Mirador de la Reina 99 (Cerro de Álamos...
# 18  [C. Mirador de la Reina, 107, 28035 Madrid Mad...
# 19  [C. Fermin Caballero, 69, 28029 Madrid Madrid,...
# 20  [Av. Monforte de Lemos, 193, 28035 Madrid Madr...
# 21   [Isla de Saipán 73, 28035 Madrid Madrid, España]
# 22               [Alfonso Rodríguez Castelao, España]
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 40.48112446689104...  40.481124 -3.723373
# 1   [{'label': 'display', 'lat': 40.49122842350793...  40.491228 -3.722157
# 2   [{'label': 'display', 'lat': 40.48678467998688...  40.486785 -3.718490
# 3   [{'label': 'display', 'lat': 40.47706381409571...  40.477064 -3.717482
# 4   [{'label': 'display', 'lat': 40.489904, 'lng':...  40.489904 -3.714280
# 5   [{'label': 'display', 'lat': 40.48914619140871...  40.489146 -3.724716
# 6   [{'label': 'display', 'lat': 40.48112023451070...  40.481120 -3.720963
# 7   [{'label': 'display', 'lat': 40.48838053202037...  40.488381 -3.717541
# 8   [{'label': 'display', 'lat': 40.4858706510018,...  40.485871 -3.718590
# 9   [{'label': 'display', 'lat': 40.48034557270606...  40.480346 -3.716651
# 10  [{'label': 'display', 'lat': 40.49059779325799...  40.490598 -3.722262
# 11  [{'label': 'display', 'lat': 40.47651545133406...  40.476515 -3.718117
# 12  [{'label': 'display', 'lat': 40.48579063622070...  40.485791 -3.718186
# 13  [{'label': 'display', 'lat': 40.48212002479462...  40.482120 -3.717547
# 14  [{'label': 'display', 'lat': 40.48454075118334...  40.484541 -3.722673
# 15  [{'label': 'display', 'lat': 40.48450797800188...  40.484508 -3.715361
# 16  [{'label': 'display', 'lat': 40.48474093558645...  40.484741 -3.720256
# 17  [{'label': 'display', 'lat': 40.489086, 'lng':...  40.489086 -3.724573
# 18  [{'label': 'display', 'lat': 40.49061956122534...  40.490620 -3.722371
# 19  [{'label': 'display', 'lat': 40.48199789977096...  40.481998 -3.711317
# 20  [{'label': 'display', 'lat': 40.47600665515477...  40.476007 -3.719769
# 21  [{'label': 'display', 'lat': 40.47923696814644...  40.479237 -3.730044
# 22  [{'label': 'display', 'lat': 40.48205674009662...  40.482057 -3.732905
#
#    neighborhood postalCode   state                        id
# 0           NaN      28035  Madrid  4b8cf54af964a52047e232e3
# 1           NaN      28049  Madrid  4c5488d1728920a1c53ee782
# 2           NaN        NaN  Madrid  50522811e4b0e2b08b3212b4
# 3   Peña Grande      28035  Madrid  59dc7ed1f62e096d40bace40
# 4           NaN      28034  Madrid  57868bb4498e8ddd7b00590d
# 5           NaN      28035  Madrid  4c11515b8559ef3b75b66a53
# 6           NaN      28035  Madrid  4b74653ef964a520e0d92de3
# 7           NaN        NaN  Madrid  4d034a74347da1cd91a4248f
# 8           NaN      28035  Madrid  4c2fcbd266e40f472a9ac28b
# 9           NaN      28035  Madrid  4ee0faa177c804cac6dbf9b3
# 10          NaN      28035  Madrid  568500f3498e7291bb023134
# 11          NaN      28035  Madrid  50040fdde4b0095178ff8474
# 12          NaN      28035  Madrid  4bbf83994cdfc9b6e6639121
# 13          NaN      28034  Madrid  4cde867369136dcbe9acd6e6
# 14          NaN      28035  Madrid  4da6e6525da37feee891e3e2
# 15          NaN      28034  Madrid  4bc63708b387d13aec7fc1e8
# 16          NaN        NaN  Madrid  4c7044203444370403a5235f
# 17          NaN        NaN  Madrid  4e13444418a84f0f03248847
# 18          NaN      28035  Madrid  4b6acd85f964a5200ee12be3
# 19          NaN      28029  Madrid  4e3e03a4ae604542366e3d90
# 20          NaN      28035  Madrid  4d6e5e602c542d43415a7aa6
# 21          NaN      28035  Madrid  4eca008e775bf65c0663eae3
# 22          NaN        NaN     NaN  54e0a07c498edc3a986299aa

# %%
#Bar
dataframe_filtered_bar = dataframe_filtered.iloc[0:0,:].copy()
cond = (dataframe_filtered['categories'] == 'Brewery')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

dataframe_filtered_bar.drop(dataframe_filtered_bar.index, inplace=True)
cond = (dataframe_filtered['categories'] == 'Bar')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Breakfast Spot')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Snack Place')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Tapas Restaurant')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Pub')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_bar = dataframe_filtered_bar.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

dataframe_filtered_bar.reset_index(inplace=True, drop=True)
dataframe_filtered_bar.head(40)
# Out:
#                       name        categories  \
# 0           Los Granadinos               Bar
# 1       Cervecería Granada               Bar
# 2      Starving Conciertos               Bar
# 3              Bar Carmelo    Breakfast Spot
# 4           Los Granadinos  Tapas Restaurant
# 5         La Ponderosa Bar  Tapas Restaurant
# 6  The Clover Irish Tavern               Pub
#
#                              address  cc    city country crossStreet  \
# 0        C. Leopoldo Alas Clarín, 53  ES  Madrid  España         NaN
# 1                                NaN  ES  Madrid  España         NaN
# 2            C. Fermin Caballero, 69  ES  Madrid  España         NaN
# 3                  Isla de Saipán 73  ES  Madrid  España         NaN
# 4  Av del Cardenal Herrera Oria, 248  ES  Madrid  España         NaN
# 5     Av. Cardenal Herrera Oria, 231  ES  Madrid  España         NaN
# 6      C. Valle de Pinares Llanos, 8  ES  Madrid  España         NaN
#
#    distance                                   formattedAddress  \
# 0        74  [C. Leopoldo Alas Clarín, 53, 28035 Madrid Mad...
# 1       131                            [Madrid Madrid, España]
# 2       937  [C. Fermin Caballero, 69, 28029 Madrid Madrid,...
# 3       923   [Isla de Saipán 73, 28035 Madrid Madrid, España]
# 4       402  [Av del Cardenal Herrera Oria, 248, 28035 Madr...
# 5       459  [Av. Cardenal Herrera Oria, 231, 28034 Madrid ...
# 6       303  [C. Valle de Pinares Llanos, 8, 28035 Madrid M...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 40.48454075118334...  40.484541 -3.722673
# 1  [{'label': 'display', 'lat': 40.48474093558645...  40.484741 -3.720256
# 2  [{'label': 'display', 'lat': 40.48199789977096...  40.481998 -3.711317
# 3  [{'label': 'display', 'lat': 40.47923696814644...  40.479237 -3.730044
# 4  [{'label': 'display', 'lat': 40.48112023451070...  40.481120 -3.720963
# 5  [{'label': 'display', 'lat': 40.48212002479462...  40.482120 -3.717547
# 6  [{'label': 'display', 'lat': 40.4858706510018,...  40.485871 -3.718590
#
#   neighborhood postalCode   state                        id
# 0          NaN      28035  Madrid  4da6e6525da37feee891e3e2
# 1          NaN        NaN  Madrid  4c7044203444370403a5235f
# 2          NaN      28029  Madrid  4e3e03a4ae604542366e3d90
# 3          NaN      28035  Madrid  4eca008e775bf65c0663eae3
# 4          NaN      28035  Madrid  4b74653ef964a520e0d92de3
# 5          NaN      28034  Madrid  4cde867369136dcbe9acd6e6
# 6          NaN      28035  Madrid  4c2fcbd266e40f472a9ac28b

# %%
#Sports
dataframe_filtered_sport = dataframe_filtered.iloc[0:0,:].copy()
cond = (dataframe_filtered['categories'] == 'Gym / Fitness Center')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_sport = dataframe_filtered_sport.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Sports Club')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_sport = dataframe_filtered_sport.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Gym')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_sport = dataframe_filtered_sport.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

cond = (dataframe_filtered['categories'] == 'Athletics & Sports')
rows = dataframe_filtered.loc[cond, :]
dataframe_filtered_sport = dataframe_filtered_sport.append(rows, ignore_index=True)
dataframe_filtered.drop(rows.index, inplace=True)

dataframe_filtered_sport.reset_index(inplace=True, drop=True)
dataframe_filtered_sport.head(40)
# Out:
#                            name            categories  \
# 0         CDM Go Fit Peñagrande  Gym / Fitness Center
# 1  La Maso Sport Center - Padel           Sports Club
# 2       Body Factory Mirasierra                   Gym
# 3         Polideportivo La Masó    Athletics & Sports
#
#                           address  cc    city country  \
# 0  Avenida Monforte de Lemos, 184  ES  Madrid  España
# 1            Calle de la Masó, 34  ES  Madrid  España
# 2         C/ Valle de en medio 15  ES  Madrid  España
# 3                  C. La Masó, 80  ES  Madrid  España
#
#                      crossStreet  distance  \
# 0                            NaN       923
# 1                            NaN       863
# 2                            NaN       548
# 3  Av. Ventisquero de la Condesa       546
#
#                                     formattedAddress  \
# 0  [Avenida Monforte de Lemos, 184, 28035 Madrid ...
# 1  [Calle de la Masó, 34, 28034 Madrid Madrid, Es...
# 2   [C/ Valle de en medio 15, Madrid Madrid, España]
# 3  [C. La Masó, 80 (Av. Ventisquero de la Condesa...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 40.47706381409571...  40.477064 -3.717482
# 1  [{'label': 'display', 'lat': 40.489904, 'lng':...  40.489904 -3.714280
# 2  [{'label': 'display', 'lat': 40.48838053202037...  40.488381 -3.717541
# 3  [{'label': 'display', 'lat': 40.48450797800188...  40.484508 -3.715361
#
#   neighborhood postalCode   state                        id
# 0  Peña Grande      28035  Madrid  59dc7ed1f62e096d40bace40
# 1          NaN      28034  Madrid  57868bb4498e8ddd7b00590d
# 2          NaN        NaN  Madrid  4d034a74347da1cd91a4248f
# 3          NaN      28034  Madrid  4bc63708b387d13aec7fc1e8

# %%
dataframe_filtered.reset_index(inplace=True, drop=True)
dataframe_filtered.head(40)
# Out:
#                                 name              categories  \
# 0   El Viejo Almacén de Buenos Aires  Argentinian Restaurant
# 1                     Tras Os Montes      Seafood Restaurant
# 2                           Singapur      Chinese Restaurant
# 3                    Mesón Las Vegas      Spanish Restaurant
# 4                   Ginos Mirasierra      Italian Restaurant
# 5                        Peggy Sue's                   Diner
# 6                             Bonsai      Chinese Restaurant
# 7                         El Mirador              Restaurant
# 8                    VIPS Mirasierra            Burger Joint
# 9            Ginos Monforte de Lemos      Italian Restaurant
# 10          Restaurante Tres Carro's              Restaurant
#
#                                         address  cc    city country  \
# 0                 C. Ramón Gómez de la Serna, 4  ES  Madrid  España
# 1                          Senda del Infante 28  ES  Madrid  España
# 2                    C. Mirador de la Reina, 99  ES  Madrid  España
# 3   Calle de la Isla de Arosa, 29, 28035 Madrid  ES  Madrid  España
# 4               C. del Mirador de la Reina, 107  ES  Madrid  España
# 5                     Av. Monforte de Lemos 185  ES  Madrid  España
# 6                       Valle Pinares Llanos, 8  ES  Madrid  España
# 7                  Calle Mirador de la Reina 99  ES  Madrid  España
# 8                   C. Mirador de la Reina, 107  ES  Madrid  España
# 9                    Av. Monforte de Lemos, 193  ES  Madrid  España
# 10                   Alfonso Rodríguez Castelao  ES     NaN  España
#
#                 crossStreet  distance  \
# 0                       NaN       416
# 1                       NaN       730
# 2                       NaN       555
# 3                       NaN       650
# 4                       NaN       660
# 5                       NaN       960
# 6                       NaN       330
# 7   Cerro de Álamos Blancos       543
# 8                       NaN       663
# 9                       NaN       980
# 10                      NaN       983
#
#                                      formattedAddress  \
# 0   [C. Ramón Gómez de la Serna, 4, 28035 Madrid M...
# 1   [Senda del Infante 28, 28049 Madrid Madrid, Es...
# 2   [C. Mirador de la Reina, 99, 28035 Madrid Madr...
# 3   [Calle de la Isla de Arosa, 29, 28035 Madrid, ...
# 4   [C. del Mirador de la Reina, 107, 28035 Madrid...
# 5   [Av. Monforte de Lemos 185, 28035 Madrid Madri...
# 6   [Valle Pinares Llanos, 8, 28035 Madrid Madrid,...
# 7   [Calle Mirador de la Reina 99 (Cerro de Álamos...
# 8   [C. Mirador de la Reina, 107, 28035 Madrid Mad...
# 9   [Av. Monforte de Lemos, 193, 28035 Madrid Madr...
# 10               [Alfonso Rodríguez Castelao, España]
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 40.48112446689104...  40.481124 -3.723373
# 1   [{'label': 'display', 'lat': 40.49122842350793...  40.491228 -3.722157
# 2   [{'label': 'display', 'lat': 40.48914619140871...  40.489146 -3.724716
# 3   [{'label': 'display', 'lat': 40.48034557270606...  40.480346 -3.716651
# 4   [{'label': 'display', 'lat': 40.49059779325799...  40.490598 -3.722262
# 5   [{'label': 'display', 'lat': 40.47651545133406...  40.476515 -3.718117
# 6   [{'label': 'display', 'lat': 40.48579063622070...  40.485791 -3.718186
# 7   [{'label': 'display', 'lat': 40.489086, 'lng':...  40.489086 -3.724573
# 8   [{'label': 'display', 'lat': 40.49061956122534...  40.490620 -3.722371
# 9   [{'label': 'display', 'lat': 40.47600665515477...  40.476007 -3.719769
# 10  [{'label': 'display', 'lat': 40.48205674009662...  40.482057 -3.732905
#
#    neighborhood postalCode   state                        id
# 0           NaN      28035  Madrid  4b8cf54af964a52047e232e3
# 1           NaN      28049  Madrid  4c5488d1728920a1c53ee782
# 2           NaN      28035  Madrid  4c11515b8559ef3b75b66a53
# 3           NaN      28035  Madrid  4ee0faa177c804cac6dbf9b3
# 4           NaN      28035  Madrid  568500f3498e7291bb023134
# 5           NaN      28035  Madrid  50040fdde4b0095178ff8474
# 6           NaN      28035  Madrid  4bbf83994cdfc9b6e6639121
# 7           NaN        NaN  Madrid  4e13444418a84f0f03248847
# 8           NaN      28035  Madrid  4b6acd85f964a5200ee12be3
# 9           NaN      28035  Madrid  4d6e5e602c542d43415a7aa6
# 10          NaN        NaN     NaN  54e0a07c498edc3a986299aa

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project I'm trying to detect the areas of my neighborhood that have low restaurant density. I will limit my analysis to a radius of ~1km around the metro station.
#
# In the first step, I have collected the required data: location and type (category) of every restaurant within 1km from the metro station of the neighborhood (Lacoma). I have also identified restaurants nearby (according to Foursquare categorization).
#
# In the second step in my analysis, I will be calculating and explorating the different restaurant radius to identify a few promising areas close to the metro station with low number of restaurants in general, and focus our attention on those areas.
#
# In the third and final step, I will analyze different sport services that are nearby the selected area to complete de studio. In the neighborhood, it is very typical to have a drink or have dinner around sports activities.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's take a look at the restaurants and pubs in the area.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the metro station

# add a red circle marker to represent the metro station
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='black',
    popup='Metro Station',
    fill = True,
    fill_color = 'black',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng, label in zip(dataframe_filtered_bar.lat, dataframe_filtered_bar.lng, dataframe_filtered_bar.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

folium.Circle([latitude, longitude], radius=250, fill=False, color='black').add_to(venues_map)
folium.Circle([latitude, longitude], radius=500, fill=False, color='black').add_to(venues_map)
folium.Circle([latitude, longitude], radius=1000, fill=False, color='black').add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's take a look at the sports centers also, as it is very typical to have a drink after sports with friends in the area.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the metro station

# add a red circle marker to represent the metro station
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='black',
    popup='Metro Station',
    fill = True,
    fill_color = 'black',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng, label in zip(dataframe_filtered_bar.lat, dataframe_filtered_bar.lng, dataframe_filtered_bar.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng, label in zip(dataframe_filtered_sport.lat, dataframe_filtered_sport.lng, dataframe_filtered_sport.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=8,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

folium.Circle([latitude, longitude], radius=250, fill=False, color='black').add_to(venues_map)
folium.Circle([latitude, longitude], radius=500, fill=False, color='black').add_to(venues_map)
folium.Circle([latitude, longitude], radius=1000, fill=False, color='black').add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# The analysis shows that although there is a good number of food places in the neighborhood (~33 in our area of interest which was 1km around the metro station), there are pockets of low food service density fairly close to sports centers. Highest concentration of restaurants was detected north and south from the metro station, so we focused our attention to east area, corresponding to a high concentration of sport centers and low food and drink services. Another borough was identified as potentially interesting (Peñagrande, south-west from the metro) as it has only one bar and two restaurants, but our attention was focused on Mirasierra which offers a combination of steady flow of people, closeness to the metro station, strong socio-economic dynamics *and* a low restaurant density.
#
# Recommended zones should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The purpose of this project was to identify areas close to Lacoma metro station with low number of restaurants (and bars) in order to starting a new food business exploiting the business opportunities due to Covid-19 impact through restaurants. There is the search for optimal location. By calculating restaurant density distribution from Foursquare data we have first identified general boroughs that justify further analysis (Mirasierra and Peñagrande) related to sport services around the areas.
#
# Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.

# %% [markdown]
# <i>Patricia Perez</i>
